# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
A_a_DFT_3 = np.loadtxt("DFT_3.dat")

# %%
plt.plot(A_a_DFT_3)

# %%
np.shape(A_a_DFT_3)
# Out:
# (512,)

# %%
A_a_FFT = np.loadtxt("FFT.dat")

# %%
plt.plot(A_a_FFT)

# %%
A_a_FFTINVERSE = np.loadtxt("FFT_INVERSE.dat")

# %%
plt.plot(A_a_FFTINVERSE)

# %%
A_a_FFT_FFT = np.loadtxt("FFT_FFT.dat")

# %%
plt.plot(A_a_FFT_FFT)

# %%
MFCC = np.loadtxt("MFCC.dat")

# %%
plt.plot(MFCC)

# %%
H = np.loadtxt("H.dat")

# %%
plt.plot(H)

# %%
correlation = np.loadtxt("correlation.dat")

# %%
plt.plot(correlation)

# %%
A_a = np.loadtxt("A_a2.dat")

# %%
plt.plot(A_a)

# %%
shift = np.loadtxt("autocorrelation_shift.dat")

# %%
plt.plot(shift)

# %%
correlation_FFT = np.loadtxt("correlation_FFT.dat")

# %%
plt.plot(correlation_FFT)

# %%
A_a_FFT = np.loadtxt("FFT.dat")#信号のFFTによる対数パワースペクトル

# %%
plt.plot(A_a_FFT)

# %%
am = np.loadtxt("Autocorrelation_modified.dat")#自己相関関数のFFT

# %%
plt.plot(am)

# %%
correlation2 = np.loadtxt("correlation2.dat")
plt.plot(correlation2)
plt.xlabel('sample')
plt.ylabel('Normalized autocorrelation')
plt.savefig('a_correlation.png')

# %%
i_correlation2 = np.loadtxt("i_correlation2.dat")
plt.plot(i_correlation2)
plt.xlabel('sample')
plt.ylabel('Normalized autocorrelation')
plt.savefig('i_correlation.png')

# %%
u_correlation2 = np.loadtxt("u_correlation2.dat")
plt.plot(u_correlation2)
plt.xlabel('sample')
plt.ylabel('Normalized autocorrelation')
plt.savefig('u_correlation.png')

# %%
e_correlation2 = np.loadtxt("e_correlation2.dat")
plt.plot(e_correlation2)
plt.xlabel('sample')
plt.ylabel('Normalized autocorrelation')
plt.savefig('e_correlation.png')

# %%
o_correlation2 = np.loadtxt("o_correlation2.dat")
plt.plot(o_correlation2)
plt.xlabel('sample')
plt.ylabel('Normalized autocorrelation')
plt.savefig('o_correlation.png')

# %%
a_autocorrelation_shift = np.loadtxt("a_autocorrelation_shift.dat")
plt.plot(a_autocorrelation_shift)
plt.xlabel('sample')
plt.ylabel('Fundamental frequency log scale')
plt.savefig('time')

# %%
aiueo3_correlation_shift = np.loadtxt("aiueo3_correlation_shift.dat")
plt.plot(aiueo3_correlation_shift)
plt.yscale("log")
plt.xlabel('shuft')
plt.ylabel('Fundamental frequency log scale')
plt.savefig('time')

# %%
aiueo1_correlation_shift = np.loadtxt("aiueo1_correlation_shift.dat")
plt.plot(aiueo1_correlation_shift)
plt.yscale("log")
plt.xlabel('shuft')
plt.ylabel('Fundamental frequency log scale')
plt.savefig('time')

# %%
aiueo6_correlation_shift = np.loadtxt("aiueo6_correlation_shift.dat")
plt.plot(aiueo6_correlation_shift)
plt.yscale("log")
plt.xlabel('shuft')
plt.ylabel('Fundamental frequency log scale')
plt.savefig('time')

# %%
aiueo1_autocorrelation = np.loadtxt("aiueo1_autocorrelation.dat")
plt.plot(aiueo1_autocorrelation)
plt.xlabel('sample')
plt.ylabel('Normalized autocorrelation')
plt.savefig('o_correlation.png')
